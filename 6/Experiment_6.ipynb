# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris=pd.read_csv('Iris.csv')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris.drop(columns="Id",inplace=True)

# %%
g=sns.relplot(x='SepalLengthCm',y='SepalWidthCm',data=iris,hue='Species',style='Species')
g.fig.set_size_inches(10,5)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='Species',y='PetalLengthCm',data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y='PetalWidthCm',data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='Species',y='SepalLengthCm',data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='Species',y='SepalWidthCm',data=iris)
plt.show()

# %%
plt.subplots(figsize=(10,7))
sns.violinplot(data=iris)
sns.swarmplot( data=iris)
plt.show()
# Out:
# c:\Users\sspat\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 10.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\sspat\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 9.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\sspat\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
iris.plot.area(y=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],alpha=0.4,figsize=(12, 6));

# %%
iris.corr(numeric_only=True)
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
plt.subplots(figsize = (8,8))
sns.heatmap(iris.corr(numeric_only=True),annot=True,fmt="f").set_title("Corelation of attributes (petal length,width and sepal length,width) among Iris species")
plt.show()

# %%
X=iris.iloc[:,0:4].values
y=iris.iloc[:,4].values

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
#Metrics
from sklearn.metrics import make_scorer, accuracy_score,precision_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score ,precision_score,recall_score,f1_score

#Model Select
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn.model_selection import train_test_split

# %%
#Train and Test split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
gaussian = GaussianNB()
gaussian.fit(X_train, y_train)
Y_pred = gaussian.predict(X_test) 
accuracy_nb=round(accuracy_score(y_test,Y_pred)* 100, 2)
acc_gaussian = round(gaussian.score(X_train, y_train) * 100, 2)

cm = confusion_matrix(y_test, Y_pred)
accuracy = accuracy_score(y_test,Y_pred)

precision =precision_score(y_test, Y_pred,average='micro')
recall =  recall_score(y_test, Y_pred,average='micro')
f1 = f1_score(y_test,Y_pred,average='micro')
print('Confusion matrix for Naive Bayes\n',cm)
print('accuracy_Naive Bayes: %.3f' %accuracy)
print('precision_Naive Bayes: %.3f' %precision)
print('recall_Naive Bayes: %.3f' %recall)
print('f1-score_Naive Bayes : %.3f' %f1)
# Out:
# Confusion matrix for Naive Bayes
#  [[16  0  0]
#  [ 0 18  0]
#  [ 0  0 11]]
# accuracy_Naive Bayes: 1.000
# precision_Naive Bayes: 1.000
# recall_Naive Bayes: 1.000
# f1-score_Naive Bayes : 1.000

# %% [markdown]
# BLOCK 1
# import numpy as np # linear algebraimport pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)import matplotlib.pyplot as pltimport seaborn as sns
# EXPLANATION :
# import → Python keyword used to load external modules (libraries) into current program memory so that their functions can be used.
# numpy → Name of the library which provides support for arrays, matrices, and mathematical operations.
# as → Keyword used to assign an alias (short name) to the imported library.
# np → Alias name given to numpy → reduces typing and improves readability.
# → Comment symbol → everything after this is ignored by Python interpreter.
# linear algebra → Refers to operations like matrix multiplication, vector operations, dot products, etc., which numpy internally performs using optimized C implementations.
# import pandas as pd →
# pandas → Library used for handling structured/tabular data (like Excel sheets).
# as pd → Alias so we can use pd instead of writing full pandas every time.
# data processing → Includes cleaning, filtering, transforming, grouping data.
# CSV file I/O →
# CSV → Comma Separated Values file format.
# I/O → Input (reading file) and Output (writing file).
# import matplotlib.pyplot as plt →
# matplotlib → Visualization library.
# pyplot → Submodule used for plotting graphs.
# plt → Alias.
# import seaborn as sns →
# seaborn → Advanced statistical visualization library built on matplotlib.
# sns → Alias.
# INTERNAL WORKING :
# When Python runs import → it loads compiled library code into RAM.
# Alias mapping is stored in namespace → so np refers to numpy module.
# WHAT WE ARE DOING :
# We are importing all required libraries for numerical operations, data handling, and visualization.
#
# BLOCK 2
# iris = pd.read_csv('Iris.csv')
# EXPLANATION :
# iris → Variable name used to store dataset.
# = → Assignment operator → assigns right-hand side result to left-hand variable.
# pd → Alias of pandas.
# . → Dot operator → used to access functions/methods inside pandas library.
# read_csv → Function used to read CSV file and convert it into DataFrame.
# ('Iris.csv') → Argument passed to function.
# ' ' → String literal → represents file name.
# INTERNAL WORKING STEP-BY-STEP :
# Step 1 → Python searches for file named Iris.csv in working directory.
# Step 2 → File is opened in read mode.
# Step 3 → Each line is read sequentially.
# Step 4 → Data is split using delimiter (comma).
# Step 5 → First row becomes column names.
# Step 6 → Remaining rows become data values.
# Step 7 → Data is structured into DataFrame (2D table).
# Step 8 → Stored in variable iris.
# WHAT WE ARE DOING :
# Loading dataset into memory.
#
# BLOCK 3
# iris.head()
# EXPLANATION :
# iris → DataFrame object.
# . → Access operator.
# head → Function of DataFrame.
# () → Function call operator.
# head() → Returns first 5 rows by default.
# INTERNAL WORKING :
# Step 1 → DataFrame indexing starts from 0.
# Step 2 → Rows 0 to 4 are selected.
# Step 3 → New DataFrame with these rows is returned.
# WHY USED :
# To quickly inspect data.
# WHAT WE ARE DOING :
# Viewing dataset preview.
#
# BLOCK 4
# iris['Species'].unique()
# EXPLANATION :
# iris → DataFrame.
# ['Species'] →
# [] → Used for column selection.
# 'Species' → Column name string.
# .unique() → Function that returns distinct values.
# INTERNAL WORKING :
# Step 1 → Column extracted as Series object.
# Step 2 → Iterate through all values.
# Step 3 → Use hashing or set-like structure to remove duplicates.
# Step 4 → Return unique values.
# WHAT WE ARE DOING :
# Identifying different classes in dataset.
#
# BLOCK 5
# iris.drop(columns="Id", inplace=True)
# EXPLANATION :
# iris → DataFrame.
# . → Access method.
# drop → Function used to remove rows or columns.
# columns="Id" → Specifies that column named "Id" should be removed.
# "Id" → String representing column name.
# inplace=True →
# inplace → Parameter controlling whether to modify original data.
# True → Boolean value meaning modify original DataFrame.
# INTERNAL WORKING :
# Step 1 → Locate column "Id" in DataFrame structure.
# Step 2 → Remove column from internal data representation.
# Step 3 → Since inplace=True → update same object instead of creating new copy.
# WHY REMOVE Id :
# Id is just serial number → does not contribute to prediction.
# WHAT WE ARE DOING :
# Cleaning dataset by removing irrelevant column.
#
# BLOCK 6
# g = sns.relplot(x='SepalLengthCm', y='SepalWidthCm', data=iris, hue='Species', style='Species')
# g.fig.set_size_inches(10,5)
# plt.show()
#
# EXPLANATION :
#
# g → Variable name used to store the object returned by relplot.
#
# = → Assignment operator → assigns output of relplot to variable g.
#
# sns → Alias of seaborn library.
#
# . → Dot operator used to access functions inside seaborn.
#
# relplot → Function used to create relational plots (scatter plot by default).
#
# ( ) → Parentheses used to pass arguments into function.
#
# x='SepalLengthCm' →
# x → Parameter specifying feature for x-axis.
# 'SepalLengthCm' → Column name (string).
#
# y='SepalWidthCm' →
# y → Parameter specifying feature for y-axis.
# 'SepalWidthCm' → Column name.
#
# data=iris →
# data → Parameter specifying dataset.
# iris → DataFrame used for plotting.
#
# hue='Species' →
# hue → Parameter used to assign different colors based on categories.
# 'Species' → Column used for color grouping.
#
# style='Species' →
# style → Parameter used to assign different marker styles.
# 'Species' → Same column used for shape differentiation.
#
# g.fig →
# g → Object returned by relplot.
# .fig → Access underlying matplotlib figure object.
#
# .set_size_inches(10,5) →
# set_size_inches → Function to set figure size.
# 10 → Width of plot.
# 5 → Height of plot.
#
# plt.show() →
# plt → matplotlib.pyplot alias.
# show() → Displays the plot.
#
# INTERNAL WORKING :
#
# Step 1 → Extract x and y columns from DataFrame.
# Step 2 → Map each row as a point (x,y).
# Step 3 → Assign color based on species using hue.
# Step 4 → Assign marker style based on species.
# Step 5 → Create legend automatically.
# Step 6 → Render figure.
#
# WHAT WE ARE DOING :
#
# We are visualizing relationship between Sepal Length and Sepal Width for different species.
#
# BLOCK 7
# plt.figure(figsize=(15,10))
# plt.subplot(2,2,1)
# sns.violinplot(x='Species',y='PetalLengthCm',data=iris)
# plt.subplot(2,2,2)
# sns.violinplot(x='Species',y='PetalWidthCm',data=iris)
# plt.subplot(2,2,3)
# sns.violinplot(x='Species',y='SepalLengthCm',data=iris)
# plt.subplot(2,2,4)
# sns.violinplot(x='Species',y='SepalWidthCm',data=iris)
# plt.show()
#
# EXPLANATION :
#
# plt.figure(figsize=(15,10)) →
# plt → matplotlib alias.
# figure → Creates a new blank figure.
# figsize=(15,10) → Tuple specifying width=15 and height=10.
#
# plt.subplot(2,2,1) →
# subplot → Divides figure into grid.
# 2 → number of rows.
# 2 → number of columns.
# 1 → position index (first plot).
#
# sns.violinplot(x='Species',y='PetalLengthCm',data=iris) →
# violinplot → Displays distribution + density.
# x='Species' → Categories.
# y='PetalLengthCm' → Numeric feature.
# data=iris → Dataset.
#
# plt.subplot(2,2,2) → Second subplot.
#
# sns.violinplot(x='Species',y='PetalWidthCm',data=iris) → Same logic for Petal Width.
#
# plt.subplot(2,2,3) → Third subplot.
#
# sns.violinplot(x='Species',y='SepalLengthCm',data=iris)
#
# plt.subplot(2,2,4) → Fourth subplot.
#
# sns.violinplot(x='Species',y='SepalWidthCm',data=iris)
#
# plt.show() → Displays all plots.
#
# INTERNAL WORKING (VERY IMPORTANT) :
#
# Violin plot uses Kernel Density Estimation (KDE).
#
# Formula :
#
# f(x) = (1 / nh) * Σ K((x - xi) / h)
#
# where
# n → number of data points
# h → bandwidth
# K → kernel function (usually Gaussian)
#
# Step-by-step :
#
# Step 1 → Data is grouped by species.
# Step 2 → For each group → density is estimated.
# Step 3 → Density mirrored to create violin shape.
# Step 4 → Median and quartiles shown inside.
#
# WHAT WE ARE DOING :
#
# We are comparing distribution of all features across species.
#
# BLOCK 8
# plt.subplots(figsize=(10,7))
# sns.violinplot(data=iris)
# sns.swarmplot(data=iris)
# plt.show()
#
# EXPLANATION :
#
# plt.subplots(figsize=(10,7)) →
# subplots → Creates figure and axes.
# figsize=(10,7) → Width and height.
#
# sns.violinplot(data=iris) →
# data=iris → Uses all numeric columns.
# Automatically plots distributions.
#
# sns.swarmplot(data=iris) →
# swarmplot → Shows individual data points.
# Adjusts positions to avoid overlap.
#
# plt.show() → Displays plot.
#
# INTERNAL WORKING :
#
# Swarmplot uses positioning algorithm:
#
# Step 1 → Points sorted by value.
# Step 2 → Placed along axis.
# Step 3 → Shifted slightly to avoid overlap.
#
# Violin plot gives distribution → swarmplot gives exact points.
#
# WHAT WE ARE DOING :
#
# Combining distribution view + actual data points.
#
# BLOCK 9
# iris.plot.area(y=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'], alpha=0.4, figsize=(12,6))
#
# EXPLANATION :
#
# iris → DataFrame.
#
# . → Access method.
#
# plot → General plotting function.
#
# .area → Specifies area chart.
#
# y=[...] →
# List of column names to plot.
# [] → List data structure.
#
# 'SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm' → Features.
#
# alpha=0.4 →
# alpha → Transparency level.
# 0.4 → Semi-transparent.
#
# figsize=(12,6) → Size of plot.
#
# INTERNAL WORKING :
#
# Step 1 → Data from each column extracted.
# Step 2 → Values stacked cumulatively.
# Step 3 → Area filled under curves.
# Step 4 → Colors assigned.
#
# WHAT WE ARE DOING :
#
# Showing cumulative variation of features.
#
# BLOCK 10
# iris.corr(numeric_only=True)
#
# EXPLANATION :
#
# iris → DataFrame.
#
# . → Access method.
#
# corr → Function to compute correlation matrix.
#
# numeric_only=True →
# numeric_only → Parameter to include only numeric columns.
# True → Boolean value.
#
# INTERNAL WORKING STEP-BY-STEP :
#
# Step 1 → Select numeric columns.
# Step 2 → For each pair of columns (x,y):
#
# Compute mean :
#
# mean_x = Σ xi / n
# mean_y = Σ yi / n
#
# Compute standard deviation :
#
# σ = sqrt( Σ (xi - mean_x)^2 / n )
#
# Compute covariance :
#
# cov(x,y) = Σ (xi - mean_x)(yi - mean_y) / n
#
# Compute correlation :
#
# r = cov(x,y) / (σx * σy)
#
# Step 3 → Store results in matrix form.
#
# WHAT WE ARE DOING :
#
# Measuring relationship strength between features.
#
# BLOCK 11
# plt.subplots(figsize = (8,8))sns.heatmap(iris.corr(numeric_only=True),annot=True,fmt="f").set_title("Corelation of attributes (petal length,width and sepal length,width) among Iris species")plt.show()
# EXPLANATION :
# plt.subplots(figsize=(8,8)) →
# plt → matplotlib.pyplot alias.
# subplots → Function that creates a figure and axes.
# figsize=(8,8) → Tuple specifying width=8 inches and height=8 inches.
# sns.heatmap(...) →
# sns → seaborn alias.
# heatmap → Function used to display matrix as color-coded grid.
# iris.corr(numeric_only=True) →
# iris → DataFrame.
# corr → Computes correlation matrix.
# numeric_only=True → Only numeric columns considered.
# annot=True →
# annot → Parameter to display values inside each cell.
# True → Enables annotation.
# fmt="f" →
# fmt → Format string.
# "f" → Float format (decimal numbers).
# .set_title(...) →
# set_title → Function to set title of plot.
# String inside represents title text.
# plt.show() → Displays plot.
# INTERNAL WORKING :
# Step 1 → Correlation matrix computed using Pearson formula.
# Step 2 → Each value mapped to color intensity.
# Step 3 → High correlation → darker color.
# Step 4 → Values printed inside cells (annot=True).
# Step 5 → Grid displayed.
# FORMULA USED :
# r = Σ[(xi - mean_x)(yi - mean_y)] / (σx * σy)
# WHAT WE ARE DOING :
# We are visually understanding relationships between features.
#
# BLOCK 12
# X = iris.iloc[:,0:4].valuesy = iris.iloc[:,4].values
# EXPLANATION :
# X → Variable storing input features.
# = → Assignment operator.
# iris → DataFrame.
# .iloc →
# iloc → Index-based selection method.
# : → Means select all rows.
# 0:4 →
# 0 → starting column index.
# 4 → ending index (exclusive).
# So columns 0,1,2,3 are selected.
# .values → Converts DataFrame into NumPy array.
# y → Variable storing target labels.
# iloc[:,4] →
# Select all rows and column at index 4.
# INTERNAL WORKING :
# Step 1 → DataFrame converted into array.
# Step 2 → Memory allocated for NumPy array.
# Step 3 → Values copied.
# WHAT WE ARE DOING :
# Separating independent variables (X) and dependent variable (y).
#
# BLOCK 13
# from sklearn.preprocessing import LabelEncoderle = LabelEncoder()y = le.fit_transform(y)
# EXPLANATION :
# from → Keyword used to import specific class from module.
# sklearn.preprocessing → Module containing preprocessing tools.
# import LabelEncoder → Class used to encode categorical labels.
# le → Variable storing encoder object.
# = → Assignment.
# LabelEncoder() → Creates instance of encoder.
# y = le.fit_transform(y) →
# fit_transform → Combines fit + transform.
# fit → Learns mapping between labels and numbers.
# transform → Converts labels into numbers.
# INTERNAL WORKING :
# Step 1 → Unique labels identified (e.g., Setosa, Versicolor, Virginica).
# Step 2 → Assign numeric values:
# Setosa → 0
# Versicolor → 1
# Virginica → 2
# Step 3 → Replace original values with numbers.
# WHY :
# Machine learning models require numeric input.
# WHAT WE ARE DOING :
# Converting categorical labels into numeric form.
#
# BLOCK 14
# from sklearn.metrics import make_scorer, accuracy_score,precision_scorefrom sklearn.metrics import classification_reportfrom sklearn.metrics import confusion_matrixfrom sklearn.metrics import accuracy_score ,precision_score,recall_score,f1_scorefrom sklearn.naive_bayes import GaussianNB
# EXPLANATION :
# make_scorer → Used to create custom scoring functions.
# accuracy_score → Measures correctness.
# precision_score → Measures exactness.
# classification_report → Detailed report of metrics.
# confusion_matrix → Matrix showing predictions vs actual.
# recall_score → Measures completeness.
# f1_score → Harmonic mean of precision and recall.
# GaussianNB → Naive Bayes classifier using Gaussian distribution.
# FORMULAS :
# Accuracy = (TP + TN) / Total
# Precision = TP / (TP + FP)
# Recall = TP / (TP + FN)
# F1 Score = 2 * (Precision * Recall) / (Precision + Recall)
# WHERE :
# TP → True Positive
# FP → False Positive
# TN → True Negative
# FN → False Negative
# NAIVE BAYES FORMULA :
# P(C|X) = [P(X|C) * P(C)] / P(X)
# GAUSSIAN FORMULA :
# P(x|C) = (1 / √(2πσ²)) * exp(-(x-μ)² / (2σ²))
# WHAT WE ARE DOING :
# Importing evaluation metrics and model.
#
# BLOCK 15
# from sklearn.model_selection import train_test_split
# EXPLANATION :
# model_selection → Module used for splitting data.
# train_test_split → Function used to divide dataset.
# WHY :
# Training → model learns
# Testing → model is evaluated
# WHAT WE ARE DOING :
# Importing function to split dataset.
#
# BLOCK 16
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
# EXPLANATION :
# X_train → Training features.
# X_test → Testing features.
# y_train → Training labels.
# y_test → Testing labels.
# train_test_split(...) → Function to split dataset.
# X → Features.
# y → Labels.
# test_size=0.3 →
# 30% data used for testing.
# 70% used for training.
# random_state=0 →
# Fixes randomness → ensures same split every time.
# INTERNAL WORKING :
# Step 1 → Data shuffled randomly.
# Step 2 → 70% assigned to training.
# Step 3 → 30% assigned to testing.
# Step 4 → Stored separately.
# WHAT WE ARE DOING :
# Dividing dataset for training and evaluation.
#
# BLOCK 17 (FINAL MODEL)
# gaussian = GaussianNB()gaussian.fit(X_train, y_train)Y_pred = gaussian.predict(X_test)accuracy_nb = round(accuracy_score(y_test,Y_pred)* 100, 2)acc_gaussian = round(gaussian.score(X_train, y_train) * 100, 2)cm = confusion_matrix(y_test, Y_pred)accuracy = accuracy_score(y_test,Y_pred)precision = precision_score(y_test, Y_pred,average='micro')recall = recall_score(y_test, Y_pred,average='micro')f1 = f1_score(y_test,Y_pred,average='micro')print('Confusion matrix for Naive Bayes\n',cm)print('accuracy_Naive Bayes: %.3f' %accuracy)print('precision_Naive Bayes: %.3f' %precision)print('recall_Naive Bayes: %.3f' %recall)print('f1-score_Naive Bayes : %.3f' %f1)
# EXPLANATION :
# gaussian = GaussianNB() →
# Creates Naive Bayes model object.
# fit(X_train, y_train) →
# Model learns patterns from training data.
# predict(X_test) →
# Predicts labels for test data.
# accuracy_score(y_test,Y_pred) →
# Compares actual vs predicted.
# round(...,2) →
# Rounds to 2 decimal places.
# confusion_matrix →
# Creates matrix of predictions.
# precision_score →
# Measures correctness of positive predictions.
# recall_score →
# Measures ability to find all positives.
# f1_score →
# Balance between precision and recall.
# average='micro' →
# Calculates metrics globally across all classes.
# print(...) → Displays output.
# INTERNAL WORKING OF NAIVE BAYES :
# Step 1 → For each class compute mean (μ) and variance (σ²).
# Step 2 → For each feature apply Gaussian formula:
# P(x|C) = (1 / √(2πσ²)) * exp(-(x-μ)² / (2σ²))
# Step 3 → Compute posterior probability:
# P(C|X) = P(X|C) * P(C)
# Step 4 → Choose class with highest probability.
# WHAT WE ARE DOING :
# Training model → predicting → evaluating performance.
#
# ✅ FINAL COMPLETE UNDERSTANDING
# WHAT WE ARE ACTUALLY DOING IN THIS ENTIRE CODE :
# Step 1 → Import libraries
# Step 2 → Load dataset
# Step 3 → Explore data
# Step 4 → Clean data
# Step 5 → Visualize patterns
# Step 6 → Analyze distributions
# Step 7 → Compute correlations
# Step 8 → Prepare input/output
# Step 9 → Encode labels
# Step 10 → Split dataset
# Step 11 → Train model
# Step 12 → Predict results
# Step 13 → Evaluate using metrics
# This is a complete Machine Learning pipeline from raw data to evaluation.
